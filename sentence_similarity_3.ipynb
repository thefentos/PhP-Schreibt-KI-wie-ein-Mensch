# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import spacy
import pandas as pd

# %%
# Lade das Modell
model = SentenceTransformer('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2')

# %%
def get_first_three_sentences(key: str):
    with open(f'exports/{key}_full.txt', 'r') as f:
        full_text = f.read()
    texts = full_text.split('--------------------NEW-TEXT------------------')

    nlp = spacy.load('de_core_news_sm')
    
    results = []
    
    for text in texts:
        # Verarbeiten des Textes mit SpaCy
        doc = nlp(text)
        
        # Filter, um Sätze zu bereinigen und sicherzustellen, dass sie nicht leer sind
        valid_sentences = [
            str(sentence).strip()
            for sentence in doc.sents
            if str(sentence).strip() not in ['', '\n', '\n\n', ' ']
        ]
        
        # Extrahieren der ersten drei gültigen Sätze
        first_three_sentences = valid_sentences[:3]
        
        # Kombinieren der Sätze in einen String und zur Ergebnisliste hinzufügen
        results.append(first_three_sentences)
    
    return results

# %%
def calculate_similarity_to_human(key='test2'):
    
    
    ai_first_sentences = get_first_three_sentences(key)
    human_first_sentences = get_first_three_sentences('human')
    
    ai_dict = {
    "first" : [text[0] for text in ai_first_sentences],
    "second" : [text[1] for text in ai_first_sentences],
    "third" : [text[2] for text in ai_first_sentences]
    }
    
    human_dict = {
    "first" : [text[0] for text in human_first_sentences],
    "second" : [text[1] for text in human_first_sentences],
    "third" : [text[2] for text in human_first_sentences]
    }
    
    results = {"first": [], "second": [], "third": []}
    
    for key in ai_dict.keys():
        ai_sentences = ai_dict[key]
        human_sentences = human_dict[key]
        result_list = results[key]
        
        for ai_sentence in ai_sentences:
            for human_sentence in human_sentences:
                
                ai_embedding = model.encode(ai_sentence).reshape(1, -1)
                human_embedding = model.encode(human_sentence).reshape(1, -1)
                cos_similarity = cosine_similarity(ai_embedding, human_embedding)
                result_list.append(cos_similarity)

        results[key] = result_list
        
    print(results.values())

    averages = [np.mean(item) for item in results.values()]
    standard_deviation = [np.std(item) for item in results.values()]


    
    return averages, standard_deviation

# %%
print(calculate_similarity_to_human('gpt4o'))
print(calculate_similarity_to_human('gpt35t'))
print(calculate_similarity_to_human('perplexity'))
print(calculate_similarity_to_human('clde'))
# Out:
# dict_values([[array([[0.3454457]], dtype=float32), array([[0.10351469]], dtype=float32), array([[0.46812463]], dtype=float32), array([[0.24579711]], dtype=float32), array([[0.23578785]], dtype=float32), array([[0.2613373]], dtype=float32), array([[0.20016104]], dtype=float32), array([[0.36073923]], dtype=float32), array([[0.09727599]], dtype=float32), array([[0.11003191]], dtype=float32), array([[0.33277202]], dtype=float32), array([[0.1900624]], dtype=float32), array([[0.07336093]], dtype=float32), array([[0.12359803]], dtype=float32), array([[0.3034734]], dtype=float32), array([[0.11347261]], dtype=float32), array([[0.36073923]], dtype=float32), array([[0.19449827]], dtype=float32), array([[0.27764958]], dtype=float32), array([[0.24908687]], dtype=float32), array([[0.0053731]], dtype=float32), array([[0.6615232]], dtype=float32), array([[0.12456976]], dtype=float32), array([[0.6917345]], dtype=float32), array([[0.36082953]], dtype=float32), array([[0.45662236]], dtype=float32), array([[0.665528]], dtype=float32), array([[0.40519044]], dtype=float32), array([[0.59239256]], dtype=float32), array([[0.30418274]], dtype=float32), array([[0.12431272]], dtype=float32), array([[0.73251796]], dtype=float32), array([[0.34914732]], dtype=float32), array([[0.8021391]], dtype=float32), array([[0.75473326]], dtype=float32), array([[0.7248265]], dtype=float32), array([[0.40519044]], dtype=float32), array([[0.09970218]], dtype=float32), array([[0.49299645]], dtype=float32), array([[0.14374432]], dtype=float32), array([[0.18199995]], dtype=float32), array([[0.09017912]], dtype=float32), array([[0.9999999]], dtype=float32), array([[0.21284063]], dtype=float32), array([[0.27891117]], dtype=float32), array([[0.41815743]], dtype=float32), array([[0.20522626]], dtype=float32), array([[0.44324288]], dtype=float32), array([[0.12607266]], dtype=float32), array([[0.10645129]], dtype=float32), array([[0.6472348]], dtype=float32), array([[0.19795465]], dtype=float32), array([[-0.0851532]], dtype=float32), array([[0.09000497]], dtype=float32), array([[0.12470297]], dtype=float32), array([[0.12603073]], dtype=float32), array([[0.44324288]], dtype=float32), array([[0.40072176]], dtype=float32), array([[0.32686546]], dtype=float32), array([[0.45660073]], dtype=float32), array([[0.13005525]], dtype=float32), array([[0.8097384]], dtype=float32), array([[0.21284063]], dtype=float32), array([[0.9999999]], dtype=float32), array([[0.34935877]], dtype=float32), array([[0.59396064]], dtype=float32), array([[0.5389416]], dtype=float32), array([[0.6534105]], dtype=float32), array([[0.4281767]], dtype=float32), array([[0.18973336]], dtype=float32), array([[0.28306407]], dtype=float32), array([[0.7701192]], dtype=float32), array([[0.43597358]], dtype=float32), array([[0.6510265]], dtype=float32), array([[0.71622765]], dtype=float32), array([[0.7801306]], dtype=float32), array([[0.6534105]], dtype=float32), array([[0.34596443]], dtype=float32), array([[0.6293913]], dtype=float32), array([[0.3254512]], dtype=float32), array([[0.10306576]], dtype=float32), array([[0.34178543]], dtype=float32), array([[0.1621042]], dtype=float32), array([[0.32375476]], dtype=float32), array([[0.51852673]], dtype=float32), array([[0.4455865]], dtype=float32), array([[0.5028803]], dtype=float32), array([[0.40091172]], dtype=float32), array([[0.5445196]], dtype=float32), array([[0.61405903]], dtype=float32), array([[0.23837933]], dtype=float32), array([[0.41284943]], dtype=float32), array([[0.18605533]], dtype=float32), array([[0.5819921]], dtype=float32), array([[0.4586122]], dtype=float32), array([[0.37485087]], dtype=float32), array([[0.40091172]], dtype=float32), array([[0.1467753]], dtype=float32), array([[0.3381622]], dtype=float32), array([[0.31356555]], dtype=float32), array([[0.14142099]], dtype=float32), array([[0.29448792]], dtype=float32), array([[0.3712123]], dtype=float32), array([[0.26156616]], dtype=float32), array([[0.24858767]], dtype=float32), array([[0.41007417]], dtype=f ...
# ([np.float32(0.39806077), np.float32(0.28834695), np.float32(0.300029)], [np.float32(0.23054153), np.float32(0.20940344), np.float32(0.17588851)])
# dict_values([[array([[0.37962225]], dtype=float32), array([[0.28622994]], dtype=float32), array([[0.3824361]], dtype=float32), array([[0.34107673]], dtype=float32), array([[0.48377734]], dtype=float32), array([[0.5913641]], dtype=float32), array([[0.32174867]], dtype=float32), array([[0.49823195]], dtype=float32), array([[0.28726542]], dtype=float32), array([[0.22337781]], dtype=float32), array([[0.33574805]], dtype=float32), array([[0.49774924]], dtype=float32), array([[0.25211552]], dtype=float32), array([[0.25102648]], dtype=float32), array([[0.3419192]], dtype=float32), array([[0.24087146]], dtype=float32), array([[0.49823195]], dtype=float32), array([[0.31405494]], dtype=float32), array([[0.34281787]], dtype=float32), array([[0.42035782]], dtype=float32), array([[0.02502259]], dtype=float32), array([[0.7486254]], dtype=float32), array([[0.08608539]], dtype=float32), array([[0.68752885]], dtype=float32), array([[0.43651015]], dtype=float32), array([[0.42573243]], dtype=float32), array([[0.6151279]], dtype=float32), array([[0.39822325]], dtype=float32), array([[0.550534]], dtype=float32), array([[0.27739656]], dtype=float32), array([[0.0786011]], dtype=float32), array([[0.6000521]], dtype=float32), array([[0.31119365]], dtype=float32), array([[0.726305]], dtype=float32), array([[0.67308986]], dtype=float32), array([[0.74927557]], dtype=float32), array([[0.39822325]], dtype=float32), array([[0.07999613]], dtype=float32), array([[0.5288178]], dtype=float32), array([[0.12952301]], dtype=float32), array([[0.18199995]], dtype=float32), array([[0.09017912]], dtype=float32), array([[0.9999999]], dtype=float32), array([[0.21284063]], dtype=float32), array([[0.27891117]], dtype=float32), array([[0.41815743]], dtype=float32), array([[0.20522626]], dtype=float32), array([[0.44324288]], dtype=float32), array([[0.12607266]], dtype=float32), array([[0.10645129]], dtype=float32), array([[0.6472348]], dtype=float32), array([[0.19795465]], dtype=float32), array([[-0.0851532]], dtype=float32), array([[0.09000497]], dtype=float32), array([[0.12470297]], dtype=float32), array([[0.12603073]], dtype=float32), array([[0.44324288]], dtype=float32), array([[0.40072176]], dtype=float32), array([[0.32686546]], dtype=float32), array([[0.45660073]], dtype=float32), array([[0.13005525]], dtype=float32), array([[0.8097384]], dtype=float32), array([[0.21284063]], dtype=float32), array([[0.9999999]], dtype=float32), array([[0.34935877]], dtype=float32), array([[0.59396064]], dtype=float32), array([[0.5389416]], dtype=float32), array([[0.6534105]], dtype=float32), array([[0.4281767]], dtype=float32), array([[0.18973336]], dtype=float32), array([[0.28306407]], dtype=float32), array([[0.7701192]], dtype=float32), array([[0.43597358]], dtype=float32), array([[0.6510265]], dtype=float32), array([[0.71622765]], dtype=float32), array([[0.7801306]], dtype=float32), array([[0.6534105]], dtype=float32), array([[0.34596443]], dtype=float32), array([[0.6293913]], dtype=float32), array([[0.3254512]], dtype=float32), array([[0.13142878]], dtype=float32), array([[0.21562493]], dtype=float32), array([[0.21158317]], dtype=float32), array([[0.24447441]], dtype=float32), array([[0.38036156]], dtype=float32), array([[0.4113046]], dtype=float32), array([[0.29961985]], dtype=float32), array([[0.35277748]], dtype=float32), array([[0.2803409]], dtype=float32), array([[0.2961566]], dtype=float32), array([[0.17777751]], dtype=float32), array([[0.41294378]], dtype=float32), array([[0.22093275]], dtype=float32), array([[0.39651692]], dtype=float32), array([[0.32310784]], dtype=float32), array([[0.23137096]], dtype=float32), array([[0.35277748]], dtype=float32), array([[0.26337117]], dtype=float32), array([[0.23062317]], dtype=float32), array([[0.20872226]], dtype=float32), array([[0.14142099]], dtype=float32), array([[0.29448792]], dtype=float32), array([[0.3712123]], dtype=float32), array([[0.26156616]], dtype=float32), array([[0.24858767]], dtype=float32), array([[0.41007417]], dty ...
# ([np.float32(0.3884837), np.float32(0.2723677), np.float32(0.3032611)], [np.float32(0.2133299), np.float32(0.19714375), np.float32(0.17500196)])
# dict_values([[array([[0.29995456]], dtype=float32), array([[0.32380503]], dtype=float32), array([[0.3877004]], dtype=float32), array([[0.37786403]], dtype=float32), array([[0.5752964]], dtype=float32), array([[0.6280524]], dtype=float32), array([[0.3401168]], dtype=float32), array([[0.49023554]], dtype=float32), array([[0.3008092]], dtype=float32), array([[0.28498358]], dtype=float32), array([[0.30645078]], dtype=float32), array([[0.51526624]], dtype=float32), array([[0.22300866]], dtype=float32), array([[0.28745604]], dtype=float32), array([[0.40156657]], dtype=float32), array([[0.29401654]], dtype=float32), array([[0.49023554]], dtype=float32), array([[0.3033527]], dtype=float32), array([[0.4196212]], dtype=float32), array([[0.4033356]], dtype=float32), array([[0.1590653]], dtype=float32), array([[0.7313546]], dtype=float32), array([[0.2777041]], dtype=float32), array([[0.799262]], dtype=float32), array([[0.46972066]], dtype=float32), array([[0.67100704]], dtype=float32), array([[0.5069047]], dtype=float32), array([[0.67047393]], dtype=float32), array([[0.40923527]], dtype=float32), array([[0.22560966]], dtype=float32), array([[0.3093461]], dtype=float32), array([[0.7961441]], dtype=float32), array([[0.34271094]], dtype=float32), array([[0.5541092]], dtype=float32), array([[0.6356153]], dtype=float32), array([[0.6361605]], dtype=float32), array([[0.67047393]], dtype=float32), array([[0.3341348]], dtype=float32), array([[0.6114957]], dtype=float32), array([[0.36482155]], dtype=float32), array([[0.18199995]], dtype=float32), array([[0.09017912]], dtype=float32), array([[0.9999999]], dtype=float32), array([[0.21284063]], dtype=float32), array([[0.27891117]], dtype=float32), array([[0.41815743]], dtype=float32), array([[0.20522626]], dtype=float32), array([[0.44324288]], dtype=float32), array([[0.12607266]], dtype=float32), array([[0.10645129]], dtype=float32), array([[0.6472348]], dtype=float32), array([[0.19795465]], dtype=float32), array([[-0.0851532]], dtype=float32), array([[0.09000497]], dtype=float32), array([[0.12470297]], dtype=float32), array([[0.12603073]], dtype=float32), array([[0.44324288]], dtype=float32), array([[0.40072176]], dtype=float32), array([[0.32686546]], dtype=float32), array([[0.45660073]], dtype=float32), array([[0.13005525]], dtype=float32), array([[0.8097384]], dtype=float32), array([[0.21284063]], dtype=float32), array([[0.9999999]], dtype=float32), array([[0.34935877]], dtype=float32), array([[0.59396064]], dtype=float32), array([[0.5389416]], dtype=float32), array([[0.6534105]], dtype=float32), array([[0.4281767]], dtype=float32), array([[0.18973336]], dtype=float32), array([[0.28306407]], dtype=float32), array([[0.7701192]], dtype=float32), array([[0.43597358]], dtype=float32), array([[0.6510265]], dtype=float32), array([[0.71622765]], dtype=float32), array([[0.7801306]], dtype=float32), array([[0.6534105]], dtype=float32), array([[0.34596443]], dtype=float32), array([[0.6293913]], dtype=float32), array([[0.3254512]], dtype=float32), array([[0.155242]], dtype=float32), array([[0.7380948]], dtype=float32), array([[0.29961807]], dtype=float32), array([[0.7821556]], dtype=float32), array([[0.5126761]], dtype=float32), array([[0.6660435]], dtype=float32), array([[0.46277878]], dtype=float32), array([[0.61055267]], dtype=float32), array([[0.35156554]], dtype=float32), array([[0.18890277]], dtype=float32), array([[0.29779118]], dtype=float32), array([[0.7303947]], dtype=float32), array([[0.30947506]], dtype=float32), array([[0.5113478]], dtype=float32), array([[0.6660107]], dtype=float32), array([[0.7557212]], dtype=float32), array([[0.61055267]], dtype=float32), array([[0.36001933]], dtype=float32), array([[0.6467549]], dtype=float32), array([[0.3403526]], dtype=float32), array([[0.19750427]], dtype=float32), array([[0.46711212]], dtype=float32), array([[0.22321753]], dtype=float32), array([[0.6628599]], dtype=float32), array([[0.18843278]], dtype=float32), array([[0.36857268]], dtype=float32), array ...
# ([np.float32(0.4154645), np.float32(0.27006766), np.float32(0.3197597)], [np.float32(0.22140945), np.float32(0.20820111), np.float32(0.17964475)])
# dict_values([[array([[0.39015445]], dtype=float32), array([[0.38203]], dtype=float32), array([[0.4438445]], dtype=float32), array([[0.5668178]], dtype=float32), array([[0.3784383]], dtype=float32), array([[0.6564631]], dtype=float32), array([[0.41093627]], dtype=float32), array([[0.7747427]], dtype=float32), array([[0.2772724]], dtype=float32), array([[0.29592496]], dtype=float32), array([[0.5320196]], dtype=float32), array([[0.55859363]], dtype=float32), array([[0.15658063]], dtype=float32), array([[0.3123132]], dtype=float32), array([[0.4312569]], dtype=float32), array([[0.31236526]], dtype=float32), array([[0.7747427]], dtype=float32), array([[0.52935076]], dtype=float32), array([[0.3595922]], dtype=float32), array([[0.5453202]], dtype=float32), array([[0.01226531]], dtype=float32), array([[0.63519347]], dtype=float32), array([[0.00355241]], dtype=float32), array([[0.56406295]], dtype=float32), array([[0.36027873]], dtype=float32), array([[0.4225494]], dtype=float32), array([[0.6086509]], dtype=float32), array([[0.3458825]], dtype=float32), array([[0.52174854]], dtype=float32), array([[0.2156538]], dtype=float32), array([[0.03214159]], dtype=float32), array([[0.72296405]], dtype=float32), array([[0.19694614]], dtype=float32), array([[0.7179375]], dtype=float32), array([[0.6378641]], dtype=float32), array([[0.59445685]], dtype=float32), array([[0.3458825]], dtype=float32), array([[0.01492519]], dtype=float32), array([[0.36193797]], dtype=float32), array([[0.07606272]], dtype=float32), array([[0.18199995]], dtype=float32), array([[0.09017912]], dtype=float32), array([[0.9999999]], dtype=float32), array([[0.21284063]], dtype=float32), array([[0.27891117]], dtype=float32), array([[0.41815743]], dtype=float32), array([[0.20522626]], dtype=float32), array([[0.44324288]], dtype=float32), array([[0.12607266]], dtype=float32), array([[0.10645129]], dtype=float32), array([[0.6472348]], dtype=float32), array([[0.19795465]], dtype=float32), array([[-0.0851532]], dtype=float32), array([[0.09000497]], dtype=float32), array([[0.12470297]], dtype=float32), array([[0.12603073]], dtype=float32), array([[0.44324288]], dtype=float32), array([[0.40072176]], dtype=float32), array([[0.32686546]], dtype=float32), array([[0.45660073]], dtype=float32), array([[0.13005525]], dtype=float32), array([[0.8097384]], dtype=float32), array([[0.21284063]], dtype=float32), array([[0.9999999]], dtype=float32), array([[0.34935877]], dtype=float32), array([[0.59396064]], dtype=float32), array([[0.5389416]], dtype=float32), array([[0.6534105]], dtype=float32), array([[0.4281767]], dtype=float32), array([[0.18973336]], dtype=float32), array([[0.28306407]], dtype=float32), array([[0.7701192]], dtype=float32), array([[0.43597358]], dtype=float32), array([[0.6510265]], dtype=float32), array([[0.71622765]], dtype=float32), array([[0.7801306]], dtype=float32), array([[0.6534105]], dtype=float32), array([[0.34596443]], dtype=float32), array([[0.6293913]], dtype=float32), array([[0.3254512]], dtype=float32), array([[0.08063494]], dtype=float32), array([[0.4774292]], dtype=float32), array([[0.23706813]], dtype=float32), array([[0.49984717]], dtype=float32), array([[0.6146628]], dtype=float32), array([[0.5567061]], dtype=float32), array([[0.5808932]], dtype=float32), array([[0.4158129]], dtype=float32), array([[0.5221395]], dtype=float32), array([[0.32218498]], dtype=float32), array([[0.18569472]], dtype=float32), array([[0.70081896]], dtype=float32), array([[0.25683635]], dtype=float32), array([[0.58076775]], dtype=float32), array([[0.5855184]], dtype=float32), array([[0.56591916]], dtype=float32), array([[0.4158129]], dtype=float32), array([[0.21118638]], dtype=float32), array([[0.50064296]], dtype=float32), array([[0.24250561]], dtype=float32), array([[0.14585695]], dtype=float32), array([[0.3073627]], dtype=float32), array([[0.37449402]], dtype=float32), array([[0.30565482]], dtype=float32), array([[0.26386288]], dtype=float32), array([[0.480953]], dtype=float32), arra ...
# ([np.float32(0.40346488), np.float32(0.3047627), np.float32(0.29431415)], [np.float32(0.23206429), np.float32(0.20051979), np.float32(0.18692055)])
